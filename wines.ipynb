# %% [markdown]
# # Load the data frame

# %%
import pandas as pd
df = pd.read_csv("wines.csv")
df[:5]
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                                  name  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %% [markdown]
# # How mane wines have been given a rating 100 points

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'name', 'points', 'price',
#        'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
len(df.loc[df['points'] == 100])
# Out:
# 19

# %% [markdown]
# # What is the name of the most expensive wine

# %%
df.loc[df["price"] == df["price"].max()]['name'].squeeze()
# Out:
# 'Glamorosa Sensible'

# %% [markdown]
# # New column that shows ratings from 0 to 5

# %%
rating_data = df['points']/20
df.insert(5, 'rating', rating_data)

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                                  name  points  rating  price  \
# 0                        Vulkà Bianco      87    4.35    NaN
# 1                            Avidagos      87    4.35   15.0
# 2                                 NaN      87    4.35   14.0
# 3                Reserve Late Harvest      87    4.35   13.0
# 4  Vintner's Reserve Wild Child Block      87    4.35   65.0
#
#             province             region_1           region_2  \
# 0  Sicily & Sardinia                 Etna                NaN
# ...

# %% [markdown]
# # Price histogram for wines than cost less than 100

# %%
df.loc[df['price'] <=100]['price'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Plot price horisontally, poins vertically

# %%
df_sorted = df.sort_values('price')
df_sorted.plot(x = 'price', y = 'points', figsize = (15,3))
# Out:
# <Axes: xlabel='price'>

# %%
df.plot(x = 'price', y = 'points', kind = 'scatter', figsize = (15,3))
# Out:
# <Axes: xlabel='price', ylabel='points'>
